# %%
itempath = 'EB-build-goods.sql'

# %%
receiptspath = '75000i.csv'

# %%
with open(receiptspath, "r") as receiptsfile:
    receiptdata = receiptsfile.read().split('\n')

# %%
receiptdata
# Out:
# ['1,1,21',
#  '1,5,11',
#  '2,1,7',
#  '2,3,11',
#  '2,4,37',
#  '2,3,45',
#  '3,5,3',
#  '3,3,42',
#  '3,3,33',
#  '4,1,5',
#  '4,2,12',
#  '4,1,47',
#  '4,4,17',
#  '5,2,42',
#  '5,5,6',
#  '5,3,18',
#  '6,4,2',
#  '6,3,4',
#  '6,4,34',
#  '7,1,15',
#  '7,4,16',
#  '7,2,23',
#  '7,3,40',
#  '8,1,34',
#  '8,2,29',
#  '8,1,2',
#  '8,3,3',
#  '9,1,36',
#  '9,2,23',
#  '9,3,26',
#  '9,5,18',
#  '9,4,35',
#  '10,4,45',
#  '10,4,44',
#  '11,2,49',
#  '11,5,17',
#  '11,4,48',
#  '11,1,38',
#  '12,4,2',
#  '12,2,3',
#  '12,3,41',
#  '12,2,21',
#  '12,5,11',
#  '12,4,37',
#  '12,2,49',
#  '13,4,43',
#  '13,1,17',
#  '13,2,48',
#  '13,1,3',
#  '14,4,35',
#  '14,4,17',
#  '14,4,43',
#  '14,5,45',
#  '15,5,43',
#  '15,5,15',
#  '15,3,37',
#  '16,3,0',
#  '16,1,46',
#  '16,4,2',
#  '16,1,20',
#  '16,5,48',
#  '17,2,17',
#  '17,5,47',
#  '18,1,14',
#  '19,5,16',
#  '19,1,39',
#  '20,5,42',
#  '20,4,13',
#  '21,1,7',
#  '21,2,11',
#  '21,5,37',
#  '21,2,45',
#  '22,3,7',
#  '22,5,15',
# ...

# %%
baskets = [line.split(", ") for line in receiptdata[0:-1]]

# %%
baskets
# Out:
# [['1,1,21'],
#  ['1,5,11'],
#  ['2,1,7'],
#  ['2,3,11'],
#  ['2,4,37'],
#  ['2,3,45'],
#  ['3,5,3'],
#  ['3,3,42'],
#  ['3,3,33'],
#  ['4,1,5'],
#  ['4,2,12'],
#  ['4,1,47'],
#  ['4,4,17'],
#  ['5,2,42'],
#  ['5,5,6'],
#  ['5,3,18'],
#  ['6,4,2'],
#  ['6,3,4'],
#  ['6,4,34'],
#  ['7,1,15'],
#  ['7,4,16'],
#  ['7,2,23'],
#  ['7,3,40'],
#  ['8,1,34'],
#  ['8,2,29'],
#  ['8,1,2'],
#  ['8,3,3'],
#  ['9,1,36'],
#  ['9,2,23'],
#  ['9,3,26'],
#  ['9,5,18'],
#  ['9,4,35'],
#  ['10,4,45'],
#  ['10,4,44'],
#  ['11,2,49'],
#  ['11,5,17'],
#  ['11,4,48'],
#  ['11,1,38'],
#  ['12,4,2'],
#  ['12,2,3'],
#  ['12,3,41'],
#  ['12,2,21'],
#  ['12,5,11'],
#  ['12,4,37'],
#  ['12,2,49'],
#  ['13,4,43'],
#  ['13,1,17'],
#  ['13,2,48'],
#  ['13,1,3'],
#  ['14,4,35'],
#  ['14,4,17'],
#  ['14,4,43'],
#  ['14,5,45'],
#  ['15,5,43'],
#  ['15,5,15'],
#  ['15,3,37'],
#  ['16,3,0'],
#  ['16,1,46'],
#  ['16,4,2'],
#  ['16,1,20'],
#  ['16,5,48'],
#  ['17,2,17'],
#  ['17,5,47'],
#  ['18,1,14'],
#  ['19,5,16'],
# ...

# %%
import numpy as np

# %%
baskets  = np.array(baskets)

# %%
baskets = baskets[:, 1:]

# %%
baskets.tolist()
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...
